# %%
import pandas as pd

# %%
df = pd.read_csv('./cereals.csv')
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843
# Apple Cinnamon Cheerios         110        2        25  29.509541
# Apple Jacks                     110        2        25  33.174094
# Basic 4                         130        3        25  37.038562
# Bran Chex                        90        2        25  49.120253
# Bran Flakes                      90        3        25  53.313813>

# %%
df [:5]
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843

# %%
df[['calories','rating','protein']]
# Out:
#                            calories     rating  protein
# name
# 100% Bran                        70  68.402973        4
# 100% Natural Bran               120  33.983679        3
# All-Bran                         70  59.425505        4
# All-Bran with Extra Fiber        50  93.704912        4
# Almond Delight                  110  34.384843        2
# Apple Cinnamon Cheerios         110  29.509541        2
# Apple Jacks                     110  33.174094        2
# Basic 4                         130  37.038562        3
# Bran Chex                        90  49.120253        2
# Bran Flakes                      90  53.313813        3

# %%
condition = df['calories'] > 70
df[condition]
# Out:
#                          calories  protein  vitamins     rating
# name
# 100% Natural Bran             120        3         0  33.983679
# Almond Delight                110        2        25  34.384843
# Apple Cinnamon Cheerios       110        2        25  29.509541
# Apple Jacks                   110        2        25  33.174094
# Basic 4                       130        3        25  37.038562
# Bran Chex                      90        2        25  49.120253
# Bran Flakes                    90        3        25  53.313813

# %%
df[(df['calories'] > 70) & (df['protein'] < 3)]
# Out:
#                          calories  protein  vitamins     rating
# name
# Almond Delight                110        2        25  34.384843
# Apple Cinnamon Cheerios       110        2        25  29.509541
# Apple Jacks                   110        2        25  33.174094
# Bran Chex                      90        2        25  49.120253

# %%
df[(df['calories'] > 70) | (df['protein'] < 3)]
# Out:
#                          calories  protein  vitamins     rating
# name
# 100% Natural Bran             120        3         0  33.983679
# Almond Delight                110        2        25  34.384843
# Apple Cinnamon Cheerios       110        2        25  29.509541
# Apple Jacks                   110        2        25  33.174094
# Basic 4                       130        3        25  37.038562
# Bran Chex                      90        2        25  49.120253
# Bran Flakes                    90        3        25  53.313813

# %%
import numpy as np
import pandas as pd

# %%
df.iloc[0:5,0:3]
# Out:
#                            calories  protein  vitamins
# name
# 100% Bran                        70        4        25
# 100% Natural Bran               120        3         0
# All-Bran                         70        4        25
# All-Bran with Extra Fiber        50        4        25
# Almond Delight                  110        2        25

# %%
df.iloc[[0,2,4],0:3]
# Out:
#                 calories  protein  vitamins
# name
# 100% Bran             70        4        25
# All-Bran              70        4        25
# Almond Delight       110        2        25

# %%
df1 = pd.DataFrame(columns=['name', 'calories', 'protein', 'vitamins', 'rating'])
df1.loc[4] = ['vignesh',110,1,23,27.75]
df1
# Out:
#       name  calories  protein  vitamins  rating
# 4  vignesh       110        1        23   27.75

# %%
# Out:
# Empty DataFrame
# Columns: [name, calories, protein, vitamins, rating]
# Index: []

# %%
df1 = df.iloc[0:9].copy()
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253

# %%
df1.drop(3,axis=0,inplace=True)
df1
# Out:
#                       name  calories  protein  vitamins     rating
# 0                100% Bran        70        4        25  68.402973
# 1        100% Natural Bran       120        3         0  33.983679
# 2                 All-Bran        70        4        25  59.425505
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253

# %%
df1.drop('name',axis=1)
df1
# Out:
#                       name  calories  protein  vitamins     rating
# 0                100% Bran        70        4        25  68.402973
# 1        100% Natural Bran       120        3         0  33.983679
# 2                 All-Bran        70        4        25  59.425505
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253

# %%
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df1['New column'] = [1,2,3,4,5,6,7,8]
df1
# Out:
#                       name  calories  protein  vitamins     rating  New column
# 0                100% Bran        70        4        25  68.402973           1
# 1        100% Natural Bran       120        3         0  33.983679           2
# 2                 All-Bran        70        4        25  59.425505           3
# 4           Almond Delight       110        2        25  34.384843           4
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541           5
# 6              Apple Jacks       110        2        25  33.174094           6
# 7                  Basic 4       130        3        25  37.038562           7
# 8                Bran Chex        90        2        25  49.120253           8

# %%
ascending_df = df.sort_values(by= 'protein')
ascending_df
# Out:
#                         name  calories  protein  vitamins     rating
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 8                  Bran Chex        90        2        25  49.120253
# 1          100% Natural Bran       120        3         0  33.983679
# 7                    Basic 4       130        3        25  37.038562
# 9                Bran Flakes        90        3        25  53.313813
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
descending_df = df.sort_values(by= 'protein',ascending=False)
descending_df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 1          100% Natural Bran       120        3         0  33.983679
# 7                    Basic 4       130        3        25  37.038562
# 9                Bran Flakes        90        3        25  53.313813
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 8                  Bran Chex        90        2        25  49.120253

# %%
df1.columns = ['col1','col2','col3','col4','col5','col6']
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df1.columns = ['col1','col2','col3','col4','col5','col6']
#       2 df1
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
# ...

# %%
df.to_csv('./files.csv',index_label=False)
files.cs

# %%
newdf = pd.read_csv('./files.csv')
newdf
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df1
# Out:
#                       col1  col2  col3  col4       col5  col6
# 0                100% Bran    70     4    25  68.402973     1
# 1        100% Natural Bran   120     3     0  33.983679     2
# 2                 All-Bran    70     4    25  59.425505     3
# 4           Almond Delight   110     2    25  34.384843     4
# 5  Apple Cinnamon Cheerios   110     2    25  29.509541     5
# 6              Apple Jacks   110     2    25  33.174094     6
# 7                  Basic 4   130     3    25  37.038562     7
# 8                Bran Chex    90     2    25  49.120253     8

# %%
df2 = df[5:8].copy()
df2
# Out:
#                       name  calories  protein  vitamins     rating
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562

# %%
df2 = df2.reset_index(drop=True)
df2
# Out:
#                       name  calories  protein  vitamins     rating
# 0  Apple Cinnamon Cheerios       110        2        25  29.509541
# 1              Apple Jacks       110        2        25  33.174094
# 2                  Basic 4       130        3        25  37.038562

# %%
pd.concat([df,df1],ignore_index=True)
# Out:
#                          name  calories  protein  vitamins     rating  \
# 0                   100% Bran      70.0      4.0      25.0  68.402973
# 1           100% Natural Bran     120.0      3.0       0.0  33.983679
# 2                    All-Bran      70.0      4.0      25.0  59.425505
# 3   All-Bran with Extra Fiber      50.0      4.0      25.0  93.704912
# 4              Almond Delight     110.0      2.0      25.0  34.384843
# 5     Apple Cinnamon Cheerios     110.0      2.0      25.0  29.509541
# 6                 Apple Jacks     110.0      2.0      25.0  33.174094
# 7                     Basic 4     130.0      3.0      25.0  37.038562
# 8                   Bran Chex      90.0      2.0      25.0  49.120253
# 9                 Bran Flakes      90.0      3.0      25.0  53.313813
# 10                        NaN       NaN      NaN       NaN        NaN
# 11                        NaN       NaN      NaN       NaN        NaN
# ...

# %%
pd.concat([df,df1])
# Out:
#                         name  calories  protein  vitamins     rating  \
# 0                  100% Bran      70.0      4.0      25.0  68.402973
# 1          100% Natural Bran     120.0      3.0       0.0  33.983679
# 2                   All-Bran      70.0      4.0      25.0  59.425505
# 3  All-Bran with Extra Fiber      50.0      4.0      25.0  93.704912
# 4             Almond Delight     110.0      2.0      25.0  34.384843
# 5    Apple Cinnamon Cheerios     110.0      2.0      25.0  29.509541
# 6                Apple Jacks     110.0      2.0      25.0  33.174094
# 7                    Basic 4     130.0      3.0      25.0  37.038562
# 8                  Bran Chex      90.0      2.0      25.0  49.120253
# 9                Bran Flakes      90.0      3.0      25.0  53.313813
# 0                        NaN       NaN      NaN       NaN        NaN
# 1                        NaN       NaN      NaN       NaN        NaN
# 2                        NaN       NaN      NaN       NaN        NaN
# ...

# %%
data = {'Gender': ['female','male','female','male'],
       'score': [86,98,55,23]}
new_df = pd.DataFrame(data)
new_df
# Out:
#    Gender  score
# 0  female     86
# 1    male     98
# 2  female     55
# 3    male     23

# %%
group = new_df.groupby(new_df['Gender']).mean()
group
# Out:
#         score
# Gender
# female   70.5
# male     60.5

# %%
from numpy import NaN

# %%
data1 = {
    'Name': ['person1', 'person2', 'person3', 'person4'],
    'Age': [28, 27, NaN, 36]
}

df = pd.DataFrame(data1)
print(df)
# Out:
#       Name   Age
# 0  person1  28.0
# 1  person2  27.0
# 2  person3   NaN
# 3  person4  36.0

# %%
data = {'Gender': ['female', 'male', 'female', 'male'],
        'score': [86, 98, NaN, 23]}
new_df = pd.DataFrame(data)
new_df = new_df.dropna()
print(new_df)
# Out:
#    Gender  score
# 0  female   86.0
# 1    male   98.0
# 3    male   23.0

# %%
data2 = {
    'Name': ['person1', 'person2', 'person3', 'person4'],
    'Age': [28, 27, 22, 36]
}

# %%
df = pd.DataFrame(data2)
df
# Out:
#       Name  Age
# 0  person1   28
# 1  person2   27
# 2  person3   22
# 3  person4   36

# %%
import pandas as pd
import numpy as np
data = {
    'Name': ['person1', 'person2', 'person3', 'person4'],
    'Age': [28, 27, np.nan, 36]
}
df = pd.DataFrame(data)
df['Age'] = df['Age'].fillna(df['Age'].mean())
print(df)
# Out:
#       Name        Age
# 0  person1  28.000000
# 1  person2  27.000000
# 2  person3  30.333333
# 3  person4  36.000000

# %%
df = pd.DataFrame(data2)
df
# Out:
#       Name  Age
# 0  person1   28
# 1  person2   27
# 2  person3   22
# 3  person4   36

# %%
df['Age'].fillna(df['Age'].median())
# Out:
# 0    28
# 1    27
# 2    22
# 3    36
# Name: Age, dtype: int64
